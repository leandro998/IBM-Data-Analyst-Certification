# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# -   Collect job data from GitHub Jobs API
# -   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'message': 'success', 'number': 7, 'people': [{'craft': 'ISS', 'name': 'Sergey Ryzhikov'}, {'craft': 'ISS', 'name': 'Kate Rubins'}, {'craft': 'ISS', 'name': 'Sergey Kud-Sverchkov'}, {'craft': 'ISS', 'name': 'Mike Hopkins'}, {'craft': 'ISS', 'name': 'Victor Glover'}, {'craft': 'ISS', 'name': 'Shannon Walker'}, {'craft': 'ISS', 'name': 'Soichi Noguchi'}]}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 7

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 7 astronauts on ISS
# And their names are :
# Sergey Ryzhikov
# Kate Rubins
# Sergey Kud-Sverchkov
# Mike Hopkins
# Victor Glover
# Shannon Walker
# Soichi Noguchi

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using GitHub Jobs API

# %% [markdown]
# Before you start doing this lab, get familier with the GitHub Jobs API.<br>
# The documentation for the GitHub Jobs API can be found at <https://jobs.github.com/api><br>
#
# <li>Understand what urls to use.<br>
# <li>Understand what parameters have to be passed.<br>
# <li>Understand the format of the output data.</li>

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# -   C
# -   C#
# -   C++
# -   Java
# -   JavaScript
# -   Python
# -   Scala
# -   Oracle
# -   SQL Server
# -   MySQL Server
# -   PostgreSQL
# -   MongoDB

# %%
#Import required libraries
import requests
import pandas as pd

# %%
baseurl = "https://jobs.github.com/positions.json"

# %% [markdown]
# Write a function to get the number of jobs for the given technology.<br>
# _Note:_ The API gives a maximum of 50 jobs per page.<br>
# If you get 50 jobs per page, it means there could be some more job listings available.<br>
# So if you get 50 jobs per page you should make another API call for next page to check for more jobs.<br>
# If you get less than 50 jobs per page, you can take it as the final count.<br>

# %%
def get_number_of_jobs(technology):
    number_of_jobs = 0
    #your code goes here
    r = requests.get(api_url)
    
    return technology,number_of_jobs

# %%
url = 'https://jobs.github.com/positions.json?description=python&location=california'
r = requests.get(url)
print(r.url)
print(r.headers['Content-Type'])
print(r.status_code)
# Out:
# https://jobs.github.com/positions.json?description=python&location=california
# application/json; charset=utf-8
# 200

# %%
r.json()
# Out:
# [{'id': '90ba4a23-0d5e-4bde-a294-32a8f0e58ab4',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/90ba4a23-0d5e-4bde-a294-32a8f0e58ab4',
#   'created_at': 'Tue Nov 10 23:16:58 UTC 2020',
#   'company': 'Gemini',
#   'company_url': 'http://www.gemini.com',
#   'location': 'San Francisco, CA',
#   'title': 'Principal Product Security Engineer',
#   'description': '<p><strong>Help Us Build the Future of Money</strong></p>\n<p>Gemini Trust Company, LLC (Gemini) is a licensed digital asset exchange and custodian. We built the Gemini platform so customers can buy, sell, and store digital assets (e.g., Bitcoin, Ethereum, and Zcash) in a regulated, secure, and compliant manner.</p>\n<p>Digital assets and blockchain technology have the power to transform the world for good. This truth, along with our core values, form the bedrock of our company and culture. At Gemini, no job is too small and no project too big as we endeavor to build the future of money. We are a mission-driven, team-based, inclusive, and determined community of thought leaders who invest in each other and the long game. Join us in our mission!</p>\n<p><strong>The Department: Security</strong></p>\n<p>In the emerging industry of digital assets, there is nothing more important than trust (which is why Gemini’s very first hires were Security experts). The Gemini Security team forms the backbone of all that we do and is as diverse as the number of challenges we tackle in the crypto space. From security architecture and engineering to maintenance of cold storage systems and data centers to cybersecurity and litigation support, our team ensures that our customers, clients, and employees are safe, secure, and supported.</p>\n<p><strong>The Role: Principal Product Security Engineer (Break)</strong></p>\n<p>As a member of the Product Security team, you will share in the responsibility of protecting the company and our customers against application security threats. The ProdSec team is focused on the advancement of modern application security and supports the engineering organization by finding, fixing, and preventing software security vulnerabilities.</p>\n<p>As a Principal Product Security Engineer, you will lead efforts to assess and review services, applications, and designs to proactively discover software vulnerabilities. This will involve working closely with multiple groups and organizations within Gemini to enable security and avoid blocking or the unnecessary slowing of development practices.</p>\n<p><strong>Responsibilities:</strong></p>\n<ul>\n<li>Execute security assessments of Gemini’s platform, which includes our web application, mobile application, and infrastructure, hardware, and protocols associated with supporting a growing list of cryptocurrencies.</li>\n<li>Develop tools that make it easier to ship secure code and harder to ship insecure code.</li>\n<li>Review and provide feedback on new features within the Gemini platform.</li>\n<li>Perform threat modeling of our platform and collaborate with engineering teams to educate them on threats and vulnerabilities applicable to Gemini’s platform.\xa0</li>\n<li>Develop and share research in the area of product security, vulnerability management, and blockchain / cryptocurrency.</li>\n</ul>\n<p><strong>Minimum Qualifications:</strong></p>\n<ul>\n<li>At least 8 years of experience in application security</li>\n<li>Expertise with common security testing methodologies</li>\n<li>Experience with automated or otherwise highly scalable application security solutions</li>\n<li>Experience with building and customizing tools</li>\n<li>Ability to accurately weigh security risks against business operations and goals</li>\n<li>Strong communication skills and ability to work in a team</li>\n</ul>\n<p><strong>Preferred Qualifications:</strong></p>\n<ul>\n<li>Experience with Scala, Python, or C++</li>\n<li>Experience with smart contracts</li>\n<li>Published or presented security research</li>\n<li>Experience securing mobile applications and infrastructure</li>\n</ul>\n<p><strong>It Pays to Work Here</strong></p>\n<p>We take a holistic approach to compensation at Gemini, which includes:</p>\n<ul>\n<li>Competitive base salaries across all departments</li>\n<li>Ownership in the company via profit sharing units</li>\n<li>Amazing benefits, 401k match contribution, and flexibl ...
#   'how_to_apply': '<p>Please apply via this link: <a href="https://grnh.se/5b45c8fc1us">https://grnh.se/5b45c8fc1us</a></p>\n<p>OR via our careers website: gemini.com/careers</p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBbXlPIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--750da7da5a9828fb4b0e0e4dd85715b432d91468/Gemini%20logo.png'},
#  {'id': '1301c4ee-a659-41c1-9906-45b084b7d639',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/1301c4ee-a659-41c1-9906-45b084b7d639',
#   'created_at': 'Tue Nov 10 23:09:07 UTC 2020',
#   'company': 'Gemini',
#   'company_url': 'http://www.gemini.com',
#   'location': 'San Francisco, CA',
#   'title': 'Senior Security Engineer',
#   'description': '<p><strong>Help Us Build the Future of Money</strong></p>\n<p>Gemini Trust Company, LLC (Gemini) is a licensed digital asset exchange and custodian. We built the Gemini platform so customers can buy, sell, and store digital assets (e.g., Bitcoin, Ethereum, and Zcash) in a regulated, secure, and compliant manner.</p>\n<p>Digital assets and blockchain technology have the power to transform the world for good. This truth, along with our core values, form the bedrock of our company and culture. At Gemini, no job is too small and no project too big as we endeavor to build the future of money. We are a mission-driven, team-based, inclusive, and determined community of thought leaders who invest in each other and the long game. Join us in our mission!</p>\n<p><strong>The Department: Security</strong>\xa0</p>\n<p>In the emerging industry of digital assets, there is nothing more important than trust (which is why Gemini’s very first hires were Security experts). The Gemini Security team forms the backbone of all that we do and is as diverse as the number of challenges we tackle in the crypto space. From security architecture and engineering to maintenance of cold storage systems and data centers to cybersecurity and litigation support, our team ensures that our customers, clients, and employees are safe, secure, and supported.</p>\n<p><strong>The Role: Senior Security Engineer, Threat Detection &amp; Response</strong></p>\n<p>Gemini is looking for a Senior Security Engineer, Threat Detection &amp; Response to join our growing information security team. In this role, you will be a technical leader within the team responsible for designing, building, and automating detection and response solutions, developing unique and creative detection mechanisms, monitoring security events, and leading responses to any security incidents. This role is based in our New York City office and will report directly to the Associate Director, Threat Detection &amp; Response.</p>\n<p><strong>Responsibilities:</strong></p>\n<ul>\n<li>Develop and deploy solutions to continuously improve the detection of and response to advanced, - targeted threats</li>\n<li>Proactively hunt for malicious activity within Gemini’s systems</li>\n<li>Research and track emerging threats, to ensure engineering teams understand relevant attacker tactics, techniques, and procedures\xa0</li>\n<li>Develop tools to automate and scale detection and response activities</li>\n<li>Support incident response and investigation efforts</li>\n</ul>\n<p><strong>Minimum Qualifications:</strong></p>\n<ul>\n<li>Proficiency in a common programming language (e.g. Python, Go)</li>\n<li>Experience developing detection mechanisms in support of MacOS, Linux systems, and cloud based solutions</li>\n<li>Experience in host, memory, and network forensics (including live response) for Windows, OSX, and/or Linux</li>\n<li>Ability to troubleshoot and debug issues, and demonstrate a methodical approach to root cause analysis</li>\n<li>Familiarity with dynamic and static analysis of malware</li>\n<li>Excellent oral and written communication skills, including the ability to interact effectively with executives, engineers, vendors and peers</li>\n</ul>\n<p><strong>Preferred Qualifications:</strong>\xa0</p>\n<ul>\n<li>Experience developing network detections and analyzing packet captures</li>\n<li>Familiarity with configuration management tools (Ansible, Chef, Puppet, etc)</li>\n<li>Strong understanding of web application and network security</li>\n<li>Experience developing and enriching threat intelligence</li>\n</ul>\n<p><strong>It Pays to Work Here</strong></p>\n<p>We take a holistic approach to compensation at Gemini, which includes:</p>\n<ul>\n<li>Competitive base salaries across all departments</li>\n<li>Ownership in the company via profit sharing units</li>\n<li>Amazing benefits, 401k match contribution, and flexible hours</li>\n<li>Snacks, Perks, Wellness Outings &amp; Events</li>\n</ul>\n<p> ...
#   'how_to_apply': '<p>Please apply via this link: <a href="https://grnh.se/4bf0616a1us">https://grnh.se/4bf0616a1us</a></p>\n<p>OR via our careers site: gemini.com/careers</p>\n',
#   'company_logo': None},
#  {'id': 'f9945a57-0454-4543-9db1-2e577ab81e64',
#   'type': 'Full Time',
#   'url': 'https://jobs.github.com/positions/f9945a57-0454-4543-9db1-2e577ab81e64',
#   'created_at': 'Mon Nov 02 20:38:19 UTC 2020',
#   'company': 'LodestoneCo.com',
#   'company_url': 'http://Lodestone',
#   'location': 'Menlo Park',
#   'title': 'Experienced Software Engineer',
#   'description': "<p>COMPANY OVERVIEW</p>\n<p>Lodestone is looking for self-motivated engineers with software engineering and machine learning experience to join our team. As a Software Engineer, you will play a key role working with our client's Product, Engineering, Analytics, and Operations teams to build key data pipelines and tools to facilitate and enable teams to effectively perform data analysis and run experimentation. You will be supporting machine learning, statistical experimentation, and data collection.</p>\n<p>WHO YOU ARE</p>\n<p>You enjoy  working with a small team in a growing company that has direct client impact. You have experience with independently leading a technical project that is client focused. You enjoy  solving technical problems and interacting with the core platform software team and product teams. This is a hybrid software engineering role, so you have a solid SWE background but are familiar with  data science, ML, and statistics. This role is responsible for handling technical support &amp; statistical analysis in our software operations support team.</p>\n<p>RESPONSIBILITIES</p>\n<p>Gather and implement technical requirements, and work closely with product and cross-functional teams to support key product initiatives</p>\n<p>Pre-process large amounts of data and feature engineering</p>\n<p>Conduct statistical modeling for analyses and report metrics and findings</p>\n<p>Enhance overall system reliability, performance, efficiency, and scalability of new platform features</p>\n<p>Configure backend and frontend software components, and tools</p>\n<p>MINIMUM QUALIFICATIONS</p>\n<p>Ability to execute independently in an ambiguous environment</p>\n<p>Ability to manage time / scope effectively and prioritize issues while maintaining the level of quality and efficiency</p>\n<p>3+ years programming experience in C, C++, Java, PHP, or Python</p>\n<p>3+ years experience in writing SQL statements</p>\n<p>2+ years experience with HTML, CSS, and JavaScript Frameworks such as REACT or similar</p>\n<p>2+ years experience with statistical testing and machine learning</p>\n<p>2+ years experience with dashboarding and data visualization</p>\n<p>3+ years industry experience in the technology sector</p>\n<p>Thorough understanding of XML, JSON, and data structure fundamentals</p>\n<p>Ability to independently and creatively solve problems</p>\n<p>PREFERRED QUALIFICATIONS</p>\n<ul>\n<li>\n<p>Undergraduate or masters degree in computer science, statistics or related technical field, or equivalent related experience</p>\n</li>\n<li>\n<p>5+ years experience software development or data science experience</p>\n</li>\n</ul>\n",
#   'how_to_apply': '<p>Email your resume to me at <a href="mailto:peta.roberts@lodestoneco.com">peta.roberts@lodestoneco.com</a></p>\n',
#   'company_logo': 'https://jobs.github.com/rails/active_storage/blobs/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBcTZOIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--b12ef9750edce3752e39d7a9dd553be726bd560d/Best_LS_Logo.png'}]

# %%
df = pd.read_json(url)

# %%
df.head()
# Out:
#                                      id       type  \
# 0  90ba4a23-0d5e-4bde-a294-32a8f0e58ab4  Full Time
# 1  1301c4ee-a659-41c1-9906-45b084b7d639  Full Time
# 2  f9945a57-0454-4543-9db1-2e577ab81e64  Full Time
#
#                                                  url  \
# 0  https://jobs.github.com/positions/90ba4a23-0d5...
# 1  https://jobs.github.com/positions/1301c4ee-a65...
# 2  https://jobs.github.com/positions/f9945a57-045...
#
#                  created_at          company            company_url  \
# 0 2020-11-10 23:16:58+00:00           Gemini  http://www.gemini.com
# 1 2020-11-10 23:09:07+00:00           Gemini  http://www.gemini.com
# 2 2020-11-02 20:38:19+00:00  LodestoneCo.com       http://Lodestone
#
#             location                                title  \
# 0  San Francisco, CA  Principal Product Security Engineer
# 1  San Francisco, CA             Senior Security Engineer
# 2         Menlo Park        Experienced Software Engineer
#
#                                          description  \
# 0  <p><strong>Help Us Build the Future of Money</...
# 1  <p><strong>Help Us Build the Future of Money</...
# 2  <p>COMPANY OVERVIEW</p>\n<p>Lodestone is looki...
#
#                                         how_to_apply  \
# 0  <p>Please apply via this link: <a href="https:...
# 1  <p>Please apply via this link: <a href="https:...
# 2  <p>Email your resume to me at <a href="mailto:...
#
#                                         company_logo
# 0  https://jobs.github.com/rails/active_storage/b...
# 1                                               None
# 2  https://jobs.github.com/rails/active_storage/b...

# %% [markdown]
# Call the function for Python and check if it is working.

# %%
print(get_number_of_jobs('python'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-966c09a24807> in <module>
# ----> 1 print(get_number_of_jobs('python'))
#
# NameError: name 'get_number_of_jobs' is not defined

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#  -->

# %%
conda install openpyxl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python-3.7-main
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     et_xmlfile-1.0.1           |          py_1001          12 KB
#     jdcal-1.4.1                |             py_0          11 KB
#     openpyxl-3.0.5             |             py_0         158 KB
#     ------------------------------------------------------------
#                                            Total:         182 KB
#
# The following NEW packages will be INSTALLED:
#
#   et_xmlfile         pkgs/main/noarch::et_xmlfile-1.0.1-py_1001
#   jdcal              pkgs/main/noarch::jdcal-1.4.1-py_0
#   openpyxl           pkgs/main/noarch::openpyxl-3.0.5-py_0
#
#
#
# Downloading and Extracting Packages
# openpyxl-3.0.5       | 158 KB    | ##################################### | 100%
# jdcal-1.4.1          | 11 KB     | ##################################### | 100%
# et_xmlfile-1.0.1     | 12 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from openpyxl import Workbook        # import Workbook class from module openpyxl
wb=Workbook()                        # create a workbook object
ws=wb.active                         # use the active worksheet
ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
ws.append(['India','Asia'])          # add another row
ws.append(['France','Europe'])       # add another row
wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx

# %%
from openpyxl import load_workbook

wb = load_workbook("countries.xlsx", data_only=True)
print(wb.sheetnames)
sh = wb["Sheet"]
print(sh["a2"].value)
# Out:
# ['Sheet']
# Eygpt

# %% [markdown]
# Create a python list of all technologies for which you need to find the number of jobs postings.

# %%
#your code goes here
skills = ['python', 'sql', 'data']
cities = ['california', 'new+york', 'london']

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
# create a main data frame:
main_df = pd.DataFrame()

# nested loop to run skills and cities:
for s in skills:
    url_skills = 'https://jobs.github.com/positions.json?description=' + s
    for c in cities:
        url = url_skills + '&location=' + c
        df = pd.read_json(url)
        main_df = main_df.append(df, ignore_index = True)
    
#check:
main_df.head()
# Out:
#                                      id       type  \
# 0  90ba4a23-0d5e-4bde-a294-32a8f0e58ab4  Full Time
# 1  1301c4ee-a659-41c1-9906-45b084b7d639  Full Time
# 2  f9945a57-0454-4543-9db1-2e577ab81e64  Full Time
# 3  6b9dce23-5790-46eb-9fbe-8090704eecef  Full Time
# 4  4926de97-addf-4f0e-afde-44b83dad5d73  Full Time
#
#                                                  url  \
# 0  https://jobs.github.com/positions/90ba4a23-0d5...
# 1  https://jobs.github.com/positions/1301c4ee-a65...
# 2  https://jobs.github.com/positions/f9945a57-045...
# 3  https://jobs.github.com/positions/6b9dce23-579...
# 4  https://jobs.github.com/positions/4926de97-add...
#
#                  created_at          company              company_url  \
# 0 2020-11-10 23:16:58+00:00           Gemini    http://www.gemini.com
# 1 2020-11-10 23:09:07+00:00           Gemini    http://www.gemini.com
# 2 2020-11-02 20:38:19+00:00  LodestoneCo.com         http://Lodestone
# 3 2020-11-13 02:28:36+00:00           Marble     http://marblepay.com
# 4 2020-11-08 23:03:35+00:00       ResoluteAI  https://www.resolute.ai
#
#             location                                title  \
# 0  San Francisco, CA  Principal Product Security Engineer
# 1  San Francisco, CA             Senior Security Engineer
# 2         Menlo Park        Experienced Software Engineer
# 3           New York                Director, Engineering
# 4      New York City                  Full Stack Engineer
#
#                                          description  \
# 0  <p><strong>Help Us Build the Future of Money</...
# 1  <p><strong>Help Us Build the Future of Money</...
# 2  <p>COMPANY OVERVIEW</p>\n<p>Lodestone is looki...
# 3  <p>Company overview:</p>\n<p>Insurance compani...
# 4  <p>ResoluteAI is a fast-growth data aggregatio...
#
#                                         how_to_apply  \
# 0  <p>Please apply via this link: <a href="https:...
# 1  <p>Please apply via this link: <a href="https:...
# 2  <p>Email your resume to me at <a href="mailto:...
# 3  <p>Apply here: <a href="https://jobs.lever.co/...
# 4  <p>Please apply at the following website:\n<a ...
#
#                                         company_logo
# 0  https://jobs.github.com/rails/active_storage/b...
# 1                                               None
# 2  https://jobs.github.com/rails/active_storage/b...
# 3  https://jobs.github.com/rails/active_storage/b...
# 4  https://jobs.github.com/rails/active_storage/b...

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here

# %% [markdown]
# Find the number of jobs postings for each of the technology in the above list.
# Write the technology name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here
main_df.drop(columns=['created_at'], inplace = True)

# %%
main_df.describe()
# Out:
#                                           id       type  \
# count                                     28         28
# unique                                    15          1
# top     4926de97-addf-4f0e-afde-44b83dad5d73  Full Time
# freq                                       3         28
#
#                                                       url company  \
# count                                                  28      28
# unique                                                 15      13
# top     https://jobs.github.com/positions/52acb8fa-e2c...  Gemini
# freq                                                    3       5
#
#                   company_url           location                title  \
# count                      28                 28                   28
# unique                     13                 13                   15
# top     http://www.gemini.com  San Francisco, CA  Full Stack Engineer
# freq                        5                  5                    3
#
#                                               description  \
# count                                                  28
# unique                                                 15
# top     <p>COMPANY OVERVIEW</p>\n<p>Lodestone is looki...
# freq                                                    3
#
#                                              how_to_apply  \
# count                                                  28
# unique                                                 15
# top     <p>Please apply at the following website:\n<a ...
# freq                                                    3
#
#                                              company_logo
# count                                                  22
# unique                                                 12
# top     https://jobs.github.com/rails/active_storage/b...
# freq                                                    3

# %%
main_df.head()
# Out:
#                                      id       type  \
# 0  90ba4a23-0d5e-4bde-a294-32a8f0e58ab4  Full Time
# 1  1301c4ee-a659-41c1-9906-45b084b7d639  Full Time
# 2  f9945a57-0454-4543-9db1-2e577ab81e64  Full Time
# 3  6b9dce23-5790-46eb-9fbe-8090704eecef  Full Time
# 4  4926de97-addf-4f0e-afde-44b83dad5d73  Full Time
#
#                                                  url          company  \
# 0  https://jobs.github.com/positions/90ba4a23-0d5...           Gemini
# 1  https://jobs.github.com/positions/1301c4ee-a65...           Gemini
# 2  https://jobs.github.com/positions/f9945a57-045...  LodestoneCo.com
# 3  https://jobs.github.com/positions/6b9dce23-579...           Marble
# 4  https://jobs.github.com/positions/4926de97-add...       ResoluteAI
#
#                company_url           location  \
# 0    http://www.gemini.com  San Francisco, CA
# 1    http://www.gemini.com  San Francisco, CA
# 2         http://Lodestone         Menlo Park
# 3     http://marblepay.com           New York
# 4  https://www.resolute.ai      New York City
#
#                                  title  \
# 0  Principal Product Security Engineer
# 1             Senior Security Engineer
# 2        Experienced Software Engineer
# 3                Director, Engineering
# 4                  Full Stack Engineer
#
#                                          description  \
# 0  <p><strong>Help Us Build the Future of Money</...
# 1  <p><strong>Help Us Build the Future of Money</...
# 2  <p>COMPANY OVERVIEW</p>\n<p>Lodestone is looki...
# 3  <p>Company overview:</p>\n<p>Insurance compani...
# 4  <p>ResoluteAI is a fast-growth data aggregatio...
#
#                                         how_to_apply  \
# 0  <p>Please apply via this link: <a href="https:...
# 1  <p>Please apply via this link: <a href="https:...
# 2  <p>Email your resume to me at <a href="mailto:...
# 3  <p>Apply here: <a href="https://jobs.lever.co/...
# 4  <p>Please apply at the following website:\n<a ...
#
#                                         company_logo
# 0  https://jobs.github.com/rails/active_storage/b...
# 1                                               None
# 2  https://jobs.github.com/rails/active_storage/b...
# 3  https://jobs.github.com/rails/active_storage/b...
# 4  https://jobs.github.com/rails/active_storage/b...

# %% [markdown]
# Save into an excel spreadsheet named 'github-job-postings.xlsx'.

# %%
#your code goes here
main_df.to_excel (r'C:\Users\leandro998\Downloads\github-job-postings.xlsx', index = None, header=True)

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
